# %%
import pandas as pd

# %%
DATA_DIR = "../data/raw/PetImages/"
categoriies = []
file_paths = []
file_names = []

# %%
import os

# %%
for class_folder in os.listdir(DATA_DIR):
    class_path = os.path.join(DATA_DIR, class_folder)
    
    if os.path.isdir(class_path) and class_folder.lower() in ['cat', 'dog']:
        print (class_folder)
# Out:
# Cat
# Dog

# %%
def split_dataset(
    raw_dir: str,
    processed_dir: str,
    test_split: float = 0.2,
    val_split: float = 0.2,
    seed: int = 42,
) -> dict:
